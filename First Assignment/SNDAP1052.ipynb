# %% [markdown]
# Creating A GitHub Repository

# %% [markdown]
# 1) Downloaded git from a google search
# 2) Signed up on Github from the main website
# 3) Clicked on create repository
# 4) Named the repository SN Data Analytics

# %% [markdown]
# Creating a folder inside repository

# %% [markdown]
# 1) On the Github main website, I clicked on new file and created a folder using the slash at the end, named it 'First Assignment'

# %% [markdown]
# Pushing an Empty Notebook to the Repository

# %% [markdown]
# 1) First installed Anaconda
# 2) Opened Jupiter and clicked on my repository 'Data Analytics'
# 3) Clicked on new, then Python 3, then renamed the notebook to 'SNDAP1052'
# 4) Opened Git and typed add main .
# 5) Then typed git commit -m 'my first commit'
# 6) Problems encountered was linking my account to Git and global email. This were resolved following the instructions
